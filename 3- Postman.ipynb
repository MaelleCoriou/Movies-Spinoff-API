# %% [markdown]
# ## APPERCU LOGICIEL POSTMAN POUR CONSULTATION D'API

# %% [markdown]
# Création de collections GET : requêtes API
#
# Les paramètres d'une API type OMDB peuvent être mis en place dans params.
# Il suffit ensuite de modifier les infos Value et cliquer sur Send pou obtenir les données souhaitées.
# Les résultats de requêtes peuvent être enregistrés dans un fichier format json.

# %%
from IPython.display import Image
Image("Pics/GET-ID-1.png")

# %%
from IPython.display import Image
Image("Pics/GET-ID-2.png")

# %%
from IPython.display import Image
Image("Pics/SEARCH-TITLE.png")
